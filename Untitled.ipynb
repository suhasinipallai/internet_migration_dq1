# %%
import pandas as pd 
import matplotlib as mpl 
import numpy as np 
import matplotlib.pyplot as plt

# %%
data_netmigration = pd.read_csv("data/net_migration.csv")

# %%
data_internetusage = pd.read_csv("data/percentage_using_internet.csv",nrows=4496)

# %%
data_netmigration1 = data_netmigration.drop('Value Footnotes', axis=1)

# %%
data_internetusage1 = data_internetusage.drop('Value Footnotes', axis=1)

# %%
data1=data_netmigration1.rename(columns ={'Country or Area':'Country','Year':'Year','Value':'Net_Migration'})

# %%
data2=data_internetusage1.rename(columns ={'Country or Area':'Country','Year':'Year','Value':'Internet_Users_Pct'})

# %%
data1.head()
# Out:
#        Country  Year  Net_Migration
# 0  Afghanistan  2012         473007
# 1  Afghanistan  2007        -677497
# 2  Afghanistan  2002         804120
# 3  Afghanistan  1997        -379474
# 4  Afghanistan  1992        2227474

# %%
data2.head()
# Out:
#        Country  Year  Internet_Users_Pct
# 0  Afghanistan  2014            6.390000
# 1  Afghanistan  2013            5.900000
# 2  Afghanistan  2012            5.454545
# 3  Afghanistan  2011            5.000000
# 4  Afghanistan  2010            4.000000

# %%
data1.shape
# Out:
# (2375, 3)

# %%
data2.shape
# Out:
# (4496, 3)

# %%
col=[data1,data2]
df = pd.concat(col)

# %%
df
# Out:
#             Country  Internet_Users_Pct  Net_Migration      Year
# 0       Afghanistan                 NaN       473007.0      2012
# 1       Afghanistan                 NaN      -677497.0      2007
# 2       Afghanistan                 NaN       804120.0      2002
# 3       Afghanistan                 NaN      -379474.0      1997
# 4       Afghanistan                 NaN      2227474.0      1992
# 5       Afghanistan                 NaN     -1484185.0      1987
# 6       Afghanistan                 NaN     -3418299.0      1982
# 7       Afghanistan                 NaN     -1117459.0      1977
# 8       Afghanistan                 NaN       -20000.0      1972
# 9       Afghanistan                 NaN       -20000.0      1967
# 10      Afghanistan                 NaN       -20000.0      1962
# 11          Albania                 NaN       -91750.0      2012
# 12          Albania                 NaN      -252926.0      2007
# ...

# %%
merge1 = pd.merge(data1,data2,on =['Country' , 'Year'],how='outer')

# %%
merge1
# Out:
#             Country      Year  Net_Migration  Internet_Users_Pct
# 0       Afghanistan      2012       473007.0                 NaN
# 1       Afghanistan      2007      -677497.0                 NaN
# 2       Afghanistan      2002       804120.0                 NaN
# 3       Afghanistan      1997      -379474.0                 NaN
# 4       Afghanistan      1992      2227474.0                 NaN
# 5       Afghanistan      1987     -1484185.0                 NaN
# 6       Afghanistan      1982     -3418299.0                 NaN
# 7       Afghanistan      1977     -1117459.0                 NaN
# 8       Afghanistan      1972       -20000.0                 NaN
# 9       Afghanistan      1967       -20000.0                 NaN
# 10      Afghanistan      1962       -20000.0                 NaN
# 11          Albania      2012       -91750.0                 NaN
# 12          Albania      2007      -252926.0                 NaN
# ...

# %%
merge1[:5]
# Out:
#        Country  Year  Net_Migration  Internet_Users_Pct
# 0  Afghanistan  2012       473007.0                 NaN
# 1  Afghanistan  2007      -677497.0                 NaN
# 2  Afghanistan  2002       804120.0                 NaN
# 3  Afghanistan  1997      -379474.0                 NaN
# 4  Afghanistan  1992      2227474.0                 NaN

# %%
merge1[-5:]
# Out:
#             Country      Year  Net_Migration  Internet_Users_Pct
# 6866       Zimbabwe      1996            NaN            0.016790
# 6867       Zimbabwe      1995            NaN            0.007684
# 6868       Zimbabwe      1994            NaN            0.001739
# 6869       Zimbabwe      1990            NaN            0.000000
# 6870  footnoteSeqID  Footnote            NaN                 NaN
